# %%
import pandas as pd
import sqlite3

# 1. Connect to the database file
conn = sqlite3.connect('/Users/udayan/CHITS_PR_1/middleware/wafer_control.db')

# 2. Write a query to select the data you want
query = "SELECT * FROM wafer_logs"

# 3. Load the data into a DataFrame
df = pd.read_sql_query(query, conn)

# 4. Close the connection
conn.close()

# View the first few rows
print(df.head())
# Out:
#    id      wafer_id            scan_time status defect_type  \
# 0   1  wafer_654229  2026-03-07 15:14:16   FAIL      Random
# 1   2  wafer_268910  2026-03-12 23:34:50   FAIL   Edge-Ring
# 2   3  wafer_791230  2026-03-12 23:52:12   FAIL    Edge-Loc
# 3   4  wafer_764692  2026-03-12 23:52:13   FAIL      Center
# 4   5  wafer_762385  2026-03-12 23:52:13   FAIL      Center
#
#                 action  confidence roi_coordinates
# 0  MOVE_TO_MICRO_STAGE        0.94  [0, 0, 33, 28]
# 1  MOVE_TO_MICRO_STAGE        0.98  [0, 0, 45, 45]
# 2  MOVE_TO_MICRO_STAGE        0.96  [0, 0, 42, 44]
# 3       ROUTE_TO_SCRAP        0.96  [0, 0, 33, 33]
# 4       ROUTE_TO_SCRAP        0.94  [0, 0, 36, 37]

# %%
df
# Out:
#     id      wafer_id            scan_time status defect_type  \
# 0    1  wafer_654229  2026-03-07 15:14:16   FAIL      Random
# 1    2  wafer_268910  2026-03-12 23:34:50   FAIL   Edge-Ring
# 2    3  wafer_791230  2026-03-12 23:52:12   FAIL    Edge-Loc
# 3    4  wafer_764692  2026-03-12 23:52:13   FAIL      Center
# 4    5  wafer_762385  2026-03-12 23:52:13   FAIL      Center
# 5    6  wafer_144917  2026-03-12 23:52:14   FAIL   Edge-Ring
# 6    7  wafer_586551  2026-03-12 23:52:15   FAIL      Center
# 7    8   wafer_82444  2026-03-12 23:52:15   FAIL    Edge-Loc
# 8    9  wafer_353112  2026-03-12 23:52:16   FAIL   Edge-Ring
# 9   10  wafer_231433  2026-03-12 23:52:16   FAIL   Edge-Ring
# 10  11  wafer_736364  2026-03-12 23:52:17   FAIL    Edge-Loc
# 11  12  wafer_157762  2026-03-12 23:52:17   FAIL   Edge-Ring
#
#                  action  confidence roi_coordinates
# 0   MOVE_TO_MICRO_STAGE        0.94  [0, 0, 33, 28]
# 1   MOVE_TO_MICRO_STAGE        0.98  [0, 0, 45, 45]
# 2   MOVE_TO_MICRO_STAGE        0.96  [0, 0, 42, 44]
# 3        ROUTE_TO_SCRAP        0.96  [0, 0, 33, 33]
# 4        ROUTE_TO_SCRAP        0.94  [0, 0, 36, 37]
# 5   MOVE_TO_MICRO_STAGE        0.98  [0, 0, 61, 61]
# 6        ROUTE_TO_SCRAP        0.98  [0, 0, 26, 23]
# 7   MOVE_TO_MICRO_STAGE        0.94  [0, 0, 41, 55]
# 8   MOVE_TO_MICRO_STAGE        0.98  [0, 0, 50, 52]
# 9   MOVE_TO_MICRO_STAGE        0.97  [0, 0, 70, 99]
# 10  MOVE_TO_MICRO_STAGE        0.93  [1, 0, 28, 31]
# 11  MOVE_TO_MICRO_STAGE        0.98  [0, 0, 61, 61]
